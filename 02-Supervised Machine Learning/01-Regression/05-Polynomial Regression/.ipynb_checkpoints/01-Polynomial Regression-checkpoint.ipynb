# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing dataset
dataset = pd.read_csv("01-Polynomial Regression.csv")
dataset.head(3)
# Out:
#            Positions  Level  Salary
# 0  Bussiness Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000

# %%
# extracting independent and dependent variable
x = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree = 3)
x_poly = pf.fit_transform(x)
lr2 = LinearRegression()
lr2.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y, color="blue")
plt.plot(x, lr.predict(x), color="red")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x,y,color="blue")  
plt.plot(x, lr2.predict(pf.fit_transform(x)), color="red")   
plt.xlabel("Position Levels")  
plt.ylabel("Salary")  
plt.show()

# %%
l_pred = lr.predict([[6.5]])
l_pred
# Out:
# array([330378.78787879])

# %%
p_pred = lr2.predict(pf.fit_transform([[6.5]]))
p_pred
# Out:
# array([133259.46969697])
